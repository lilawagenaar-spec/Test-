# %% [markdown]
# # Problem 1: Numerical integration of the SIR model

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

from spicy.integrate import odeint

# %%
#function that returns dy/dt
def model(y,t):
    df

#initial condition
S + I + R = 1

# %%
#from resolvig ODEs
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

#function that returns dy/dt
def model(y,t):
    k = 0.3
    dydt = -y + 1
    return dydt

#initial condition
y0 = 0

#time points
t = np.linspace(0,20, 100) #create an array of 100 evenly spaced points between 0 and 20
#solve ODE
y = odeint(model,y0,t)
#plot results
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()
